# %%
import pandas as pd
import numpy as np
from operator import concat

# %%
# ruta de kernelB donde se almacenara las bases depuradas
kernelB='C://Users//miavila//Desktop//SCRIPS  - ALEX/'

# %% [markdown]
# # All bases Backups persona natural

# %% [markdown]
# # carpeta 2019
# + 01 Base de tabulación PN - Junio a Octubre.xlsx--------------Contiene de junio a octubre 2018
#   + Fecha | Hora	| Dirección de correo electrónico	| Número de identificación del Cliente | Tipo Call center | Seleccione el motivo | Seleccione producto | Gestión realizada
# ___
#
# + 02 Base de tabulación PN - Noviembre a Marzo.xlsx--------------Contiene noviembre y diciembre 2018 & ENERO, FEBRERO, MARZO 2019
#    + Fecha | Hora	| Dirección de correo electrónico	| Número de identificación del Cliente | Tipo Call center | Seleccione el motivo | Seleccione producto | Gestión realizada
#
# ___
# + 04 abril.xlsx
#    + Fecha |	Hora | Correo |	Cedula | Call origen | Producto | Motivo | Gestión | Asesor	| Call | Coordinador |	Jefatura
# ___
# + 05 Mayo.xlsx
#   + Fecha |	Hora | Correo |	Cedula | Call origen | Producto | Motivo | Gestión | Asesor	| Call | Coordinador |	Jefatura
#  ___
# + 06 Junio.xlsx
#   + Fecha |	Hora | Correo |	Cedula | Call origen | Producto | Motivo | Gestión | Asesor	| Call | Coordinador |	Jefatura
#  ___
# + 07 Julio.xlsx
#   + Fecha |	Hora | Correo |	Cedula | Call origen | Producto | Motivo | Gestión | Asesor	| Call | Coordinador |	Jefatura | Mes
#  ___
# + 08 Tabulación persona natural Agosto.xlsx
#   + Fecha |	Usuario	| _______ |	Numero de Cedula	| Call	| Producto |	Motivo	| Gestion	| llamada de oficina	| Ext |	Nombre Asesor	| Depto	| Coord	| CALL	| Mes
# ___
# + Septiembre.xlsx
#    + Fecha | 	Usuario |	Numero de Cedula | Call	| Producto |	Motivo	| Gestion |	llamada de oficina	| Ext |	Nombre Asesor	 | Depto |	Coord	| CALL | 	Mes
# ___
# + Tabulación persona natural 2019_10_04.xlsx------------Contiene mes de septiembre y los 2 primeros dias de octubre.
#    + Fecha | 	Usuario |	Numero de Cedula | Call	| Producto |	Motivo	| Gestion |	llamada de oficina	| Ext |	Nombre Asesor	 | Depto |	Coord	| CALL | 	Mes
# ___
# + Tabulación persona natural Octubre 2019.xlsx
#    + Fecha | 	Usuario |	Numero de Cedula | Call	| Producto |	Motivo	| Gestion |	llamada de oficina	| Ext |	Nombre Asesor	 | Depto |	Coord	| CALL | 	Mes
# ___
# + Tabulación persona natural Noviembre 2019.xlsx
#    + Fecha | 	Usuario |	Numero de Cedula | Call	| Producto |	Motivo	| Gestion |	llamada de oficina	| Ext |	Nombre Asesor	 | Depto |	Coord	| CALL | 	Mes
# ___
# + Tabulacion PN -Diciembre 2019.xlsx
#   +  Fecha | 	Usuario |	Numero de Cedula | Call	| Producto |	Motivo	| Gestion |	llamada de oficina	| codigo de oficina
# __
# + Tabulación Call center consolidado Abril  - Septiembre.xlsx--------- contiene solo septiembre
#   + Fecha |	Producto  | 	Motivo

# %%
#_____2019_____
#___________________________________________________________________________________________________________________________________________________________
kernel1='C://Users//miavila//Desktop//SCRIPS  - ALEX//Backups//Backups persona natural//2019//2019//'
# Fecha | Hora	| Dirección de correo electrónico	| Número de identificación del Cliente | Tipo Call center | Seleccione el motivo | Seleccione producto | Gestión realizada

df2018_6_10=pd.read_excel(kernel1 +'01 Base de tabulación PN - Junio a Octubre.xlsx')
df2019_11_3=pd.read_excel(kernel1 +'02 Base de tabulación PN - Noviembre a Marzo.xlsx')
df2019_4=pd.read_excel(kernel1 +'04 abril.xlsx')
df2019_5=pd.read_excel(kernel1 +'05 Mayo.xlsx')
df2019_6=pd.read_excel(kernel1 +'06 Junio.xlsx')
df2019_7=pd.read_excel(kernel1 +'07 Julio.xlsx')
df2019_8=pd.read_excel(kernel1 +'08 Tabulación persona natural Agosto.xlsx')
df2019_9=pd.read_excel(kernel1 +'Septiembre.xlsx')
df2019_9_2=pd.read_excel(kernel1 + 'Tabulación persona natural 2019_10_04.xlsx')
df2019_10=pd.read_excel(kernel1 + 'Tabulación persona natural Octubre 2019.xlsx')
df2019_11=pd.read_excel(kernel1 + 'Tabulación persona natural Noviembre 2019.xlsx')
df2019_12=pd.read_excel(kernel1 + 'Tabulacion PN -Diciembre 2019.xlsx')
#  df2018_6_10,df2019_11_3,df2019_4,df2019_5,df2019_6,df2019_7,df2019_8,df2019_9,df2019_9_2,df2019_10,df2019_11,df2019_12

#_____2020_____
#___________________________________________________________________________________________________________________________________________________________
kernel2='C://Users//miavila//Desktop//SCRIPS  - ALEX//Backups//Backups persona natural//2020//2020//'
# Fecha	| Usuario	| Numero de Cedula	| Call	| Producto | 	Motivo	|Gestion | 	llamada de oficina | codigo de oficina

df2020_1=pd.read_excel(kernel2 +'01 Tabulacion PN - Enero 2020.xlsx')
df2020_2=pd.read_excel(kernel2 +'02 Tabulación PN - Febrero 2020.xlsx')
df2020_3_5=pd.read_excel(kernel2 +'03 Tabulación PN -  Marzo a Mayo 2020.xlsx')
df2020_6=pd.read_excel(kernel2 +'06 Tabulación PN - Junio 2020.xlsx')
df2020_7=pd.read_excel(kernel2 +'07 Tabulación PN - Julio 2020.xlsx')
df2020_8=pd.read_excel(kernel2 +'08 Tabulación PN - Agosto 2020.xlsx')
df2020_9=pd.read_excel(kernel2 +'09 Tabulación PN - Septiembre 2020.xlsx')
df2020_10=pd.read_excel(kernel2 +'10 Tabulación PN - Octubre.xlsx')
df2020_11=pd.read_excel(kernel2 +'11 Tabulación PN - Noviembre 2020.xlsx')
df2020_12=pd.read_excel(kernel2 +'12 Tabulación PN - Diciembre 2020.xlsx')
#df2020_1,df2020_2,df2020_3_5,df2020_6,df2020_7,df2020_8,df2020_9,df2020_10,df2020_11,df2020_12

#_____2021_____
#____________________________________________________________________________________________________________________________________________________________
kernel3='C://Users//miavila//Desktop//SCRIPS  - ALEX//Backups//Backups persona natural//2021//2021//'
#Fecha | Usuario | Numero de Cedula | Producto | Motivos      
                                                                     #nombre de la hoja
df2021_1=pd.read_excel(kernel3 +'01 Tabulación PN - Enero 2021.xlsx',sheet_name='Base')
df2021_2=pd.read_excel(kernel3 +'02 Tabulación PN - Febrero 2021.xlsx',sheet_name='Base')
df2021_3=pd.read_excel(kernel3 +'03 Tabulación PN - Marzo 2021.xlsx',sheet_name='Base')
df2021_4=pd.read_excel(kernel3 +'04 Tabulación PN - Abril 2021.xlsx',sheet_name='Base')
df2021_5=pd.read_excel(kernel3 +'05 Tabulación PN - Mayo 2021.xlsx',sheet_name='Base')
df2021_6=pd.read_excel(kernel3 +'06 Tabulación PN - Junio 2021.xlsx',sheet_name='Base')         # COLUMNAS ADICIONALES:  Celular | Cantidad de comunicaciones
df2021_7=pd.read_excel(kernel3 +'07 Tabulación PN - Julio 2021.xlsx',sheet_name='Base')         # COLUMNAS ADICIONALES:  Celular | Cantidad de comunicaciones
df2021_8=pd.read_excel(kernel3 +'08 Tabulación PN - Agosto 2021.xlsx',sheet_name='Base')        # COLUMNAS ADICIONALES:  Celular | Cantidad de comunicaciones
df2021_9=pd.read_excel(kernel3 +'09 Tabulación PN - Septiembre 2021.xlsx',sheet_name='Base')    # COLUMNAS ADICIONALES:  Celular | Cantidad de comunicaciones
df2021_10=pd.read_excel(kernel3 +'10 Tabulación PN - Octubre 2021.xlsx',sheet_name='Base')      # COLUMNAS ADICIONALES:  Celular | Cantidad de comunicaciones
df2021_11=pd.read_excel(kernel3 +'11 Tabulación PN - Noviembre 2021.xlsx',sheet_name='Base')    # COLUMNAS ADICIONALES:  Celular | Cantidad de comunicaciones
df2021_12=pd.read_excel(kernel3 +'12 Tabulación PN - Diciembre 2021.xlsx',sheet_name='Base')    # COLUMNAS ADICIONALES:  Celular | Cantidad de comunicaciones

#_____2022_____
#_____________________________________________________________________________________________________________________________________________________________
kernel4='C://Users//miavila//Desktop//SCRIPS  - ALEX//Backups//Backups persona natural//2022//2022//'
#Fecha | Usuario | Numero de Cedula | Producto | Motivos                                                                    
                                                                 #nombre de la hoja
df2022_1=pd.read_excel(kernel4 +'01 Tabulación PN - Enero 2022.xlsx',sheet_name='Base')         # COLUMNAS ADICIONALES:  Celular | Cantidad de comunicaciones
df2022_2=pd.read_excel(kernel4 +'02 Tabulación PN - Febrero 2022.xlsx',sheet_name='Base')       # COLUMNAS ADICIONALES:  Celular | Cantidad de comunicaciones
df2022_3=pd.read_excel(kernel4 +'03 Tabulación PN - Marzo 2022.xlsx',sheet_name='Base')         # COLUMNAS ADICIONALES:  ID | Marca en el extarior
df2022_4=pd.read_excel(kernel4 +'04 Tabulación PN - Abril 2022.xlsx',sheet_name='Base')         # COLUMNAS ADICIONALES:  ID | Marca en el extarior
df2022_5=pd.read_excel(kernel4 +'05 Tabulación PN - Mayo 2022.xlsx',sheet_name='Base')          # COLUMNAS ADICIONALES:  ID | Marca en el extarior
df2022_6=pd.read_excel(kernel4 +'06 Tabulación PN - Junio 2022.xlsx',sheet_name='Base')         # COLUMNAS ADICIONALES:  ID | Marca en el extarior
df2022_7=pd.read_excel(kernel4 +'07 Tabulación PN - Julio 2022.xlsx',sheet_name='Base')         # COLUMNAS ADICIONALES:  ID | Marca en el extarior
df2022_8=pd.read_excel(kernel4 +'08 Tabulación PN - Agosto 2022.xlsx',sheet_name='Base')        # COLUMNAS ADICIONALES:  ID | Marca en el extarior
df2022_9=pd.read_excel(kernel4 +'09 Tabulación PN - Septiembre 2022.xlsx',sheet_name='Base')    # COLUMNAS ADICIONALES:  ID | Marca en el extarior
df2022_10=pd.read_excel(kernel4 +'10 Tabulación PN - Octubre 2022.xlsx',sheet_name='Base')      # COLUMNAS ADICIONALES:  ID | Marca en el extarior
#df2022_11=pd.read_excel(kernel +'11 Tabulación PN - Noviembre 2022.xlsx',sheet_name='Base')
#df2022_12=pd.read_excel(kernel +'12 Tabulación PN - Diciembre 2022.xlsx',sheet_name='Base')

# %% [markdown]
# ### RENOMBRAMIENTO
# Fecha | Mes | Usuario | Numero de Cedula | Producto |Motivos ||| ID ||| Marca en el Exterior

# %%
#  df2018_6_10,df2019_11_3,df2019_4,df2019_5,df2019_6,df2019_7,df2019_8,df2019_9,df2019_9_2,df2019_10,df2019_11,df2019_12
df2019_8.columns
# Out:
# Index(['Fecha', 'Usuario', 'Numero de Cedula', 'Call', 'Producto ', 'Motivo',
#        'Gestion', 'llamada de oficina', 'Ext', 'Nombre Asesor', 'Depto',
#        'Coord', 'CALL', 'Mes'],
#       dtype='object')

# %%
df2018_6_10.rename(columns={'Dirección de correo electrónico':'Usuario','Número de identificación del Cliente':'Numero de Cedula','Seleccione el motivo':'Motivos',
'Seleccione producto':'Producto'},inplace=True)
df2019_11_3.rename(columns={'Dirección de correo electrónico':'Usuario','Número de identificación del Cliente':'Numero de Cedula','Seleccione el motivo':'Motivos',
'Seleccione producto':'Producto'},inplace=True)

df2019_4_7=pd.concat([df2019_4,df2019_5,df2019_6,df2019_7],axis=0)
df2019_4_7.rename(columns={'Correo':'Usuario','Cedula':'Numero de Cedula','Motivo':'Motivos'},inplace=True)

df2019_8.rename(columns={'Motivo':'Motivos'},inplace=True)
#df2019_8.drop(columns=['Unnamed: 2'],inplace=True)

df2019_9_12=pd.concat([df2019_9,df2019_9_2,df2019_10,df2019_11,df2019_12],axis=0)
df2019_9_12.rename(columns={'Motivo':'Motivos'},inplace=True)
#____df2018_6_10,df2019_11_3,df2019_4_7,df2019_8,df2019_9_12

#2020
#  df2020_1,df2020_2,df2020_3_5,df2020_6,df2020_7,df2020_8,df2020_9,df2020_10,df2020_11,df2020_12
#df2020_3_5.drop(columns=['mes'],inplace=True)
df2020_1_5=pd.concat([df2020_1,df2020_2,df2020_3_5],axis=0)
df2020_1_5.rename(columns={'Motivo':'Motivos'},inplace=True)

df2020_6.rename(columns={'desbloqueo de Productos Monitoreo':'Motivos'},inplace=True)
df2020_7.rename(columns={'desbloqueo de Productos Monitoreo':'Motivos'},inplace=True)
df2020_8.rename(columns={'desbloqueo de Productos Monitoreo':'Motivos'},inplace=True)
df2020_9.rename(columns={'desbloqueo de Productos Monitoreo':'Motivos'},inplace=True)
df2020_10.rename(columns={'Motivo':'Motivos'},inplace=True)
df2020_11.rename(columns={'Motivo':'Motivos','Producto':'Producto '},inplace=True)
df2020_12.rename(columns={'Producto':'Producto '},inplace=True)

# %%
df2020_11.columns,df2020_12.columns
# Out:
# (Index(['Fecha', 'Usuario', 'Numero de Cedula', 'Producto ', 'Motivos'], dtype='object'),
#  Index(['Fecha', 'Usuario', 'Numero de Cedula', 'Producto ', 'Motivos'], dtype='object'))

# %% [markdown]
# ### ordenamiento

# %%
df2018_6_10=pd.DataFrame(df2018_6_10,columns=['Fecha', 'Usuario', 'Numero de Cedula',
        'Producto', 'Motivos'])
df2019_11_3=pd.DataFrame(df2019_11_3,columns=['Fecha', 'Usuario', 'Numero de Cedula',
        'Producto', 'Motivos'])
df2019_4_7=pd.DataFrame(df2019_4_7,columns=['Fecha', 'Usuario', 'Numero de Cedula',
        'Producto', 'Motivos'])
df2019_8=pd.DataFrame(df2019_8,columns=['Fecha', 'Usuario', 'Numero de Cedula',
        'Producto', 'Motivos'])
df2019_9_12=pd.DataFrame(df2019_9_12,columns=['Fecha', 'Usuario', 'Numero de Cedula',
        'Producto', 'Motivos'])
#_____________________________________________________________________________________

df2020_1_5=pd.DataFrame(df2020_1_5,columns=['Fecha', 'Usuario', 'Numero de Cedula',
        'Producto ', 'Motivos'])



df2020_6=pd.DataFrame(df2020_6,columns=['Fecha', 'Usuario', 'Numero de Cedula',
        'Producto ', 'Motivos'])

df2020_7=pd.DataFrame(df2020_7,columns=['Fecha', 'Usuario', 'Numero de Cedula',
        'Producto ', 'Motivos'])

df2020_8=pd.DataFrame(df2020_8,columns=['Fecha', 'Usuario', 'Numero de Cedula',
        'Producto ', 'Motivos'])

df2020_9=pd.DataFrame(df2020_9,columns=['Fecha', 'Usuario', 'Numero de Cedula',
        'Producto ', 'Motivos'])

df2020_10=pd.DataFrame(df2020_10,columns=['Fecha', 'Usuario', 'Numero de Cedula',
        'Producto ', 'Motivos'])

df2020_11=pd.DataFrame(df2020_11,columns=['Fecha', 'Usuario', 'Numero de Cedula',
        'Producto ', 'Motivos'])
df2020_12=pd.DataFrame(df2020_12,columns=['Fecha', 'Usuario', 'Numero de Cedula',
        'Producto ', 'Motivos'])

# %%
# Fecha |  Usuario | Numero de Cedula | Producto |  Motivos    ||| ID ||| Marca en el Exterior |||  Mes

# %%
DF2018_2022_1_2= pd.concat([DF2018,DF2019,DF2020,DF2021,DF2022_1_2],axis=0)

# %%
DF2018_2022_1_2
# Out:
#                          Fecha                                     Usuario  \
# 0      2018-06-05 00:00:00.000            leidyj.rodriguezd@davivienda.com
# 1      2018-06-05 00:00:00.000             jeysonf.buitrago@davivienda.com
# 2      2018-06-05 00:00:00.000             jeysonf.buitrago@davivienda.com
# 3      2018-06-05 00:00:00.000             jeysonf.buitrago@davivienda.com
# 4      2018-06-05 00:00:00.000             jeysonf.buitrago@davivienda.com
# ...                        ...                                         ...
# 270340 2022-02-28 23:53:30.799                     aamargon@davivienda.com
# 270341 2022-02-28 23:54:15.222                     aamargon@davivienda.com
# 270342 2022-02-28 23:54:44.468   kelly.quintero@proveedores.davivienda.com
# 270343 2022-02-28 23:55:27.592  cristian.suarez@proveedores.davivienda.com
# 270344 2022-02-28 23:57:15.565   kelly.quintero@proveedores.davivienda.com
#
#        Numero de Cedula             Producto  \
# ...

# %%
def etl():   
     #'Fecha', 'Usuario', 'Numero de Cedula','Producto', 'Motivos'
    DF2018=pd.concat([df2018_6_10,df2019_11_3], axis=0,)
    
     #'Fecha', 'Usuario', 'Numero de Cedula','Producto', 'Motivos'
    DF2019=pd.concat([df2019_4_7, df2019_8,df2019_9_12],axis=0)
    
     #'Fecha', 'Usuario', 'Numero de Cedula','Producto', 'Motivos'
    DF2020= pd.concat([df2020_1_5,df2020_6,df2020_7,df2020_8,df2020_9,df2020_10,df2020_11,df2020_12],axis=0)
    DF2020.rename(columns={'Producto ':'Producto'},inplace=True) #

     #'Fecha', 'Usuario', 'Numero de Cedula','Producto', 'Motivos' | Celular	Cantidad de comunicaciones
    DF2021=pd.concat([df2021_1,df2021_2,df2021_3,df2021_4,df2021_5,df2021_6,df2021_7,df2021_8,df2021_9,df2021_10,df2021_11,df2021_12], axis=0,)
    DF2021=pd.DataFrame(DF2021,columns=[ 'Fecha','Usuario','Numero de Cedula','Producto', 'Motivos'])

     #'Fecha', 'Usuario', 'Numero de Cedula','Producto', 'Motivos' | 	Celular	Cantidad de comunicaciones
    DF2022_1_2=pd.concat([df2022_1,df2022_2],axis=0,)
    DF2022_1_2=pd.DataFrame(DF2022_1_2,columns=[ 'Fecha','Usuario','Numero de Cedula','Producto', 'Motivos'])
     
    # UNIR
    DF2018_2022_1_2= pd.concat([DF2018,DF2019,DF2020,DF2021,DF2022_1_2],axis=0)
    DF2018_2022_1_2['ID']=np.nan
    DF2018_2022_1_2['Marca en el extarior']=np.nan
     # crear columna ID Y Marca en el Exterior
    DF2022_3_10=pd.concat([df2022_3,df2022_4,df2022_5,df2022_6,df2022_7,df2022_8,df2022_9,df2022_10],axis=0,)

    # Unión final
    DF=pd.concat([DF2018_2022_1_2,DF2022_3_10],axis=0)
    DF['Fecha']= DF['Fecha'].dt.date.astype(str)  # extrae solo año,mes,dia
    DF['Fecha'] =pd.to_datetime(DF['Fecha'])
    DF.index = range(DF.shape[0])

    #CREAR COLUMNAS CORRESPONDIENTES A MES, DIA DEL MES, DIA DE LA SEMANA (INGLES)
    DF=DF.assign(Año= DF.Fecha.dt.year, MesN=DF.Fecha.dt.month   ,Dia_MesN=DF.Fecha.dt.day) 
    
    DF.to_csv(kernelB+ 'UNIFICACIÓN 2018-2022.csv')
    return(DF)
pass
DF=pd.DataFrame(etl());DF
# Out:
#               Fecha                               Usuario Numero de Cedula  \
# 0        2018-06-05      leidyj.rodriguezd@davivienda.com         80865792
# 1        2018-06-05       jeysonf.buitrago@davivienda.com       1014193850
# 2        2018-06-05       jeysonf.buitrago@davivienda.com       1090450755
# 3        2018-06-05       jeysonf.buitrago@davivienda.com         32317050
# 4        2018-06-05       jeysonf.buitrago@davivienda.com         51898447
# ...             ...                                   ...              ...
# 13502785 2022-10-31   llvarvar@proveedores.davivienda.com       17773627.0
# 13502786 2022-10-31  wendynope@proveedores.davivienda.com        8785001.0
# 13502787 2022-10-31   llvarvar@proveedores.davivienda.com       16986708.0
# 13502788 2022-10-31  wendynope@proveedores.davivienda.com       79596885.0
# 13502789 2022-10-31   llvarvar@proveedores.davivienda.com       39792341.0
#
#                                             Producto  \
# ...

# %%
DF.columns
# Out:
# Index(['Fecha', 'Usuario', 'Numero de Cedula', 'Producto', 'Motivos', 'ID',
#        'Marca en el extarior', 'Año', 'MesN', 'Dia_MesN'],
#       dtype='object')

# %%
#DF.Producto.value_counts(),DF.Motivos.value_counts()
